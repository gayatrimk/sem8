# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('HousingData.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222     18.7  396.90    NaN  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273     21.0  391.99    NaN  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
data=df

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 5    0.02985   0.0   2.18   0.0  0.458  ...  222     18.7  394.12   5.21  28.7
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 499  0.17783   0.0   9.69   0.0  0.585  ...  391     19.2  395.77  15.10  17.5
# 500  0.22438   0.0   9.69   0.0  0.585  ...  391     19.2  396.90  14.33  16.8
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273     21.0  393.45   6.48  22.0
#
# [394 rows x 14 columns]

# %%
X=df.drop('MEDV',axis=1)
Y=df['MEDV'].values.reshape(-1,1)

# %%
Xtr,xte,ytr,yte=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
sx = StandardScaler()
X_train_scaled = sx.fit_transform(Xtr)
X_te_scaled = sx.transform(xte)

Y_train = ytr
Y_test = yte

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

# %%
model.add(Dense(128,input_shape=(13,),activation='relu',name='input'))
model.add(Dense(64,activation='relu',name='layer1'))
model.add(Dense(1,name='output'))
model.compile(optimizer='adam',loss='mse',metrics=['mae'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (Dense)                   │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer1 (Dense)                  │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,113 (39.50 KB)
#  Trainable params: 10,113 (39.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train_scaled, Y_train, epochs=100, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 557.8495 - mae: 21.5426 - val_loss: 472.8777 - val_mae: 20.3086
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 489.7890 - mae: 20.1148 - val_loss: 423.1066 - val_mae: 19.0616
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 457.4160 - mae: 19.1487 - val_loss: 363.1574 - val_mae: 17.4585
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 370.5673 - mae: 16.9530 - val_loss: 291.2248 - val_mae: 15.3398
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 291.5049 - mae: 14.8729 - val_loss: 209.9154 - val_mae: 12.6483
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 176.4467 - mae: 11.3049 - val_loss: 133.7101 - val_mae: 9.5242
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 141.6465 - mae: 9.6594 - val_loss: 78.6889 - val_mae: 6.7543
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 59.1188 - mae: 6.2012 - val_loss: 57.9648 - val_mae: 5.5100
# ...

# %%
output = model.evaluate(X_te_scaled, Y_test)
print(f"Test Loss: {output[0]:.4f}, Test MAE: {output[1]:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 26.1727 - mae: 2.6839
# Test Loss: 24.0725, Test MAE: 2.6490

# %%
y_pred=model.predict(X_te_scaled)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
y_pred
# Out:
# array([[25.271786],
#        [20.450485],
#        [17.731524],
#        [28.182495],
#        [17.603645],
#        [35.296165],
#        [18.98489 ],
#        [28.749859],
#        [31.956123],
#        [14.37315 ],
#        [17.13403 ],
#        [48.6319  ],
#        [21.718521],
#        [19.159393],
#        [22.290659],
#        [22.877632],
#        [15.987178],
#        [17.235775],
#        [22.663265],
#        [11.418852],
#        [19.38511 ],
#        [17.395454],
#        [14.366505],
#        [27.821133],
#        [25.429153],
#        [15.439201],
#        [27.469013],
#        [30.544355],
#        [21.696688],
#        [27.476627],
#        [46.24345 ],
#        [15.128168],
#        [26.824652],
#        [17.145779],
#        [19.590055],
#        [17.873611],
#        [18.794512],
#        [21.851166],
#        [23.95612 ],
#        [17.906586],
#        [28.200125],
#        [40.056866],
#        [23.083033],
#        [30.958492],
#        [37.476025],
# ...
